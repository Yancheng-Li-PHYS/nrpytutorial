# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import mpmath as mp
import csv

def file_reader(filename):
    with open(filename) as file:
        reader = csv.reader(file, delimiter=" ")
        data  = list(zip(*reader))
        data0 = []
        data1 = []
        data2 = []
        data3 = []
        for i in range(len(data[0])):           
            data0.append(float(data[0][i]))
            data1.append(float(data[1][i]))
            data2.append(float(data[2][i]))
            data3.append(float(data[3][i]))
        return data0,data1,data2,data3

def file_reader2(filename):
    with open(filename) as file:
        reader = csv.reader(file, delimiter=" ")
        data  = list(zip(*reader))
        data0 = []
        data1 = []
        data2 = []
        data3 = []
        data4 = []
        for i in range(len(data[0])):           
            data0.append(float(data[0][i]))
            data1.append(float(data[1][i]))
            data2.append(float(data[2][i]))
            data3.append(float(data[3][i]))
            data4.append(float(data[3][i]))
        return data0,data1,data2,data3,data4

# %%
filename = "Curvilinear__resolution_16x8x16_iter_0"
x_iter_0,y_iter_0,num_0,exact_0 = file_reader(filename+".txt")
fig = plt.figure()
ax = fig.add_subplot(111)
#ax = plt.axes(projection='3d')
ax.set_xlabel('x_coord')
ax.set_ylabel('y_coord')
#ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 16x8x16-resolution')
#ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
ax.scatter(x_iter_0,y_iter_0)
plt.show()

# %%
import numpy as np
from mpl_toolkits import mplot3d
import mpl_toolkits.mplot3d.axes3d as axes3d

filename = "Curvilinear__resolution_16x16x16_iter_0"
x_iter_0,y_iter_0,num_0,exact_0 = file_reader(filename+".txt")
fig = plt.figure()
#ax = fig.add_subplot(111)
ax = plt.axes(projection='3d')
ax.set_xlabel('x_coord')
ax.set_ylabel('y_coord')
ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 3D 16x16x16-resolution')
ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)

plt.show()

# %%
itermax = 1405
i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_16x16x16_iter_"+str(i)
    x_iter_0,y_iter_0,num_0,exact_0 = file_reader(filename+".txt")
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.set_xlabel('x_coord')
    ax.set_ylabel('y_coord')
    ax.set_zlabel('Numerical Soln.')
    ax.set_title('CurvilinearWave 3D 16*16*16-resolution')
    ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
    savefig(filename+".png",dpi=450)
    plt.close(fig)
    i += 30

# %%
import matplotlib.image as mgimg
from matplotlib import animation

fig = plt.figure(frameon=False)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')

myimages = []

i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_16x16x16_iter_"+str(i)
    img = mgimg.imread(filename+".png")
    imgplot = plt.imshow(img)
    myimages.append([imgplot])
    i += 30

ani = animation.ArtistAnimation(fig, myimages, interval=100,  repeat_delay=1000)
plt.close()
ani.save("CurvilinearWave 3D 16x16x16_resolution.mp4", fps=5,dpi=450)

# %%
HTML("""
    <video width="480" height="360" controls>
        <source src="CurvilinearWave 3D 16x16x16_resolution.mp4" type="video/mp4"> 
    </video>
""")
# Out:
#     <video width="480" height="360" controls>
#         <source src="CurvilinearWave 3D 16x16x16_resolution.mp4" type="video/mp4">
#     </video>

# %%
from mpl_toolkits import mplot3d
from matplotlib.pyplot import savefig

itermax = 705
i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_16x8x16_iter_"+str(i)
    x_iter_0,y_iter_0,num_0,exact_0 = file_reader(filename+".txt")
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.set_xlabel('x_coord')
    ax.set_ylabel('y_coord')
    ax.set_zlabel('Numerical Soln.')
    ax.set_title('CurvilinearWave 3D low-resolution')
    ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
    savefig(filename+".png",dpi=450)
    plt.close(fig)
    i += 15

# %%
import matplotlib.image as mgimg
from matplotlib import animation

fig = plt.figure(frameon=False)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')

myimages = []

i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_16x8x16_iter_"+str(i)
    img = mgimg.imread(filename+".png")
    imgplot = plt.imshow(img)
    myimages.append([imgplot])
    i += 15

ani = animation.ArtistAnimation(fig, myimages, interval=100,  repeat_delay=1000)
plt.close()
ani.save("CurvilinearWave 3D low-resolution.mp4", fps=5,dpi=450)

# %%
from IPython.display import HTML
#the filename needed to be changed manually

HTML("""
    <video width="480" height="360" controls>
        <source src="CurvilinearWave 3D low-resolution.mp4" type="video/mp4"> 
    </video>
""")
# Out:
#     <video width="480" height="360" controls>
#         <source src="CurvilinearWave 3D low-resolution.mp4" type="video/mp4">
#     </video>

# %%
filename = "Curvilinear__resolution_16x32x16_iter_0"
x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
fig = plt.figure()
#ax = fig.add_subplot(111)
ax = plt.axes(projection='3d')
ax.set_xlabel('x_coord')
ax.set_ylabel('y_coord')
ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 16x32x16-resolution')
ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
#ax.scatter(x_iter_0,y_iter_0)
plt.show()

fig2 = plt.figure()
#ax = fig.add_subplot(111)
ax = plt.axes(projection='3d')
ax.set_xlabel('x_coord')
ax.set_ylabel('y_coord')
ax.set_zlabel('z_coord')
ax.set_title('CurvilinearWave 16x32x16-resolution')
ax.scatter3D(x_iter_0,y_iter_0,z_iter_0, c=z_iter_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
#ax.scatter(x_iter_0,y_iter_0)
plt.show()

# %%
filename = "Curvilinear__resolution_16x32x16_iter_0"
x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
fig = plt.figure()
ax = fig.add_subplot(111)
plt.gca().set_aspect('equal', adjustable='box')
plt.figure(figsize=((10,10)))
#ax = plt.axes(projection='3d')
ax.set_xlabel('x_coord')
ax.set_ylabel('y_coord')
#ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 16x8x16-resolution')
#ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
ax.scatter(x_iter_0,y_iter_0,s=2)
plt.show()

# %%
filename = "Curvilinear__resolution_16x32x16_iter_0"
x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
fig = plt.figure()
ax = fig.add_subplot(111)
plt.gca().set_aspect('equal', adjustable='box')
plt.figure(figsize=((10,10)))
#ax = plt.axes(projection='3d')
ax.set_xlabel('x_coord')
ax.set_ylabel('z_coord')
#ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 16x8x16-resolution')
#ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
ax.scatter(x_iter_0,z_iter_0,s=0.2)
plt.show()

# %%
filename = "Curvilinear__resolution_16x32x16_iter_0"
x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
fig = plt.figure()
ax = fig.add_subplot(111)
plt.gca().set_aspect('equal', adjustable='box')
plt.figure(figsize=((10,10)))
#ax = plt.axes(projection='3d')
ax.set_xlabel('y_coord')
ax.set_ylabel('z_coord')
#ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 16x8x16-resolution')
#ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
ax.scatter(y_iter_0,z_iter_0,s=0.2)
plt.show()

# %%
itermax = 1735
i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_16x32x16_iter_"+str(i)
    x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.set_xlabel('x_coord')
    ax.set_ylabel('y_coord')
    ax.set_zlabel('Numerical Soln.')
    ax.set_title('CurvilinearWave 3D 16*16*16-resolution')
    ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
    savefig(filename+".png",dpi=450)
    plt.close(fig)
    i += 40

# %%
import matplotlib.image as mgimg
from matplotlib import animation

fig = plt.figure(frameon=False)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')

myimages = []

i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_16x32x16_iter_"+str(i)
    img = mgimg.imread(filename+".png")
    imgplot = plt.imshow(img)
    myimages.append([imgplot])
    i += 40

ani = animation.ArtistAnimation(fig, myimages, interval=100,  repeat_delay=1000)
plt.close()
ani.save("CurvilinearWave 3D 16x32x16_resolution.mp4", fps=5,dpi=450)

# %%
from IPython.display import HTML
#the filename needed to be changed manually

HTML("""
    <video width="480" height="360" controls>
        <source src="CurvilinearWave 3D 16x32x16_resolution.mp4" type="video/mp4"> 
    </video>
""")
# Out:
#     <video width="480" height="360" controls>
#         <source src="CurvilinearWave 3D 16x32x16_resolution.mp4" type="video/mp4">
#     </video>

# %%
itermax = 1735
i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_16x32x16_iter_"+str(i)
    x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.set_xlabel('y_coord')
    ax.set_ylabel('z_coord')
    ax.set_zlabel('Numerical Soln.')
    ax.set_title('CurvilinearWave 3D 16*16*16-resolution')
    ax.scatter3D(y_iter_0,z_iter_0,num_0, c=num_0, cmap='Greens')
    savefig(filename+"_yz.png",dpi=450)
    plt.close(fig)
    i += 40

# %%
import matplotlib.image as mgimg
from matplotlib import animation

fig = plt.figure(frameon=False)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')

myimages = []

i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_16x32x16_iter_"+str(i)
    img = mgimg.imread(filename+"_yz.png")
    imgplot = plt.imshow(img)
    myimages.append([imgplot])
    i += 40

ani = animation.ArtistAnimation(fig, myimages, interval=100,  repeat_delay=1000)
plt.close()
ani.save("CurvilinearWave 3D yz 16x32x16_resolution.mp4", fps=5,dpi=450)

# %%
from IPython.display import HTML
#the filename needed to be changed manually

HTML("""
    <video width="480" height="360" controls>
        <source src="CurvilinearWave 3D yz 16x32x16_resolution.mp4" type="video/mp4"> 
    </video>
""")
# Out:
#     <video width="480" height="360" controls>
#         <source src="CurvilinearWave 3D yz 16x32x16_resolution.mp4" type="video/mp4">
#     </video>

# %%
filename = "Curvilinear__resolution_16x32x2_iter_0"
x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
fig = plt.figure()
#ax = fig.add_subplot(111)
ax = plt.axes(projection='3d')
ax.set_xlim3d(-1, 1)
#ax.set_ylim3d(0,1000)
#ax.set_zlim3d(0,1000)
ax.set_xlabel('x_coord')
ax.set_ylabel('y_coord')
ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 16x32x2-resolution')
ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
#ax.scatter(x_iter_0,y_iter_0)
plt.show()

fig2 = plt.figure()
#ax = fig.add_subplot(111)
ax = plt.axes(projection='3d')
ax.set_xlim3d(-1, 1)
ax.set_xlabel('x_coord')
ax.set_ylabel('y_coord')
ax.set_zlabel('z_coord')
ax.set_title('CurvilinearWave 16x32x2-resolution')
ax.scatter3D(x_iter_0,y_iter_0,z_iter_0, c=z_iter_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
#ax.scatter(x_iter_0,y_iter_0)
plt.show()

# %%
itermax = 550
i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_16x32x2_iter_"+str(i)
    x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
    fig = plt.figure()
    ax = plt.axes(projection='3d')
    ax.set_xlabel('x_coord')
    ax.set_ylabel('y_coord')
    ax.set_zlabel('Numerical Soln.')
    ax.set_title('CurvilinearWave 3D 16x32x2-resolution')
    ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
    savefig(filename+".png",dpi=450)
    plt.close(fig)
    i += 15

# %%
import matplotlib.image as mgimg
from matplotlib import animation

fig = plt.figure(frameon=False)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')

myimages = []

i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_16x32x2_iter_"+str(i)
    img = mgimg.imread(filename+".png")
    imgplot = plt.imshow(img)
    myimages.append([imgplot])
    i += 15

ani = animation.ArtistAnimation(fig, myimages, interval=100,  repeat_delay=1000)
plt.close()
ani.save("CurvilinearWave 3D 16x32x2_resolution.mp4", fps=5,dpi=450)

# %%
from IPython.display import HTML
#the filename needed to be changed manually

HTML("""
    <video width="480" height="360" controls>
        <source src="CurvilinearWave 3D 16x32x2_resolution.mp4" type="video/mp4"> 
    </video>
""")
# Out:
#     <video width="480" height="360" controls>
#         <source src="CurvilinearWave 3D 16x32x2_resolution.mp4" type="video/mp4">
#     </video>

# %%
filename = "Curvilinear__resolution_256x128x256_iter_0"
x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
fig = plt.figure()
#ax = fig.add_subplot(111)
ax = plt.axes(projection='3d')
ax.set_xlabel('x_coord')
ax.set_ylabel('y_coord')
ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 256x128x256-resolution')
ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
#ax.scatter(x_iter_0,y_iter_0)
plt.show()

# %%
filename = "Curvilinear__resolution_256x128x256_iter_0"
x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
fig = plt.figure()
ax = fig.add_subplot(111)
#plt.gca().set_aspect('equal', adjustable='box')
#plt.figure(figsize=((10,10)))
#ax = plt.axes(projection='3d')
ax.set_xlabel('x_coord')
ax.set_ylabel('Numerical Soln.')
#ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 256x128x256-resolution')
#ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
ax.scatter(x_iter_0,num_0,s=0.0001)
plt.show()

# %%
filename = "Curvilinear__resolution_72x12x2_iter_200"
x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
fig = plt.figure()
#ax = fig.add_subplot(111)
ax = plt.axes(projection='3d')
ax.set_xlabel('x_coord')
ax.set_ylabel('y_coord')
ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 72x12x2-resolution')
ax.scatter3D(x_iter_0,y_iter_0,num_0, s=5, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
#ax.scatter(x_iter_0,y_iter_0)
plt.show()

# %%
filename = "Curvilinear__resolution_72x12x2_iter_0"
x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
fig = plt.figure()
ax = fig.add_subplot(111)
#plt.gca().set_aspect('equal', adjustable='box')
#plt.figure(figsize=((10,10)))
#ax = plt.axes(projection='3d')
ax.set_xlabel('x_coord')
ax.set_ylabel('Numerical Soln.')
#ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 72x12x2-resolution')
#ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
ax.scatter(x_iter_0,num_0,s=2)
plt.show()

# %%
filename = "Curvilinear__resolution_72x12x2_iter_0"
x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
fig = plt.figure()
ax = fig.add_subplot(111)
#plt.gca().set_aspect('equal', adjustable='box')
#plt.figure(figsize=((10,10)))
#ax = plt.axes(projection='3d')
ax.set_xlabel('y_coord')
ax.set_ylabel('Numerical Soln.')
#ax.set_zlabel('Numerical Soln.')
ax.set_title('CurvilinearWave 72x12x2-resolution')
#ax.scatter3D(x_iter_0,y_iter_0,num_0, c=num_0, cmap='Greens')
#ax.plot_trisurf(
#    np.array(x_iter_0),np.array(y_iter_0),np.array(num_0),  cmap=plt.get_cmap('jet'),
#    linewidth=0, antialiased=False, alpha=0.5)
ax.scatter(y_iter_0,num_0,s=2)
plt.show()

# %%
itermax = 440
i = 0
while i <= itermax:
    
    filename = "Curvilinear__resolution_72x12x2_iter_"+str(i)
    x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
    fig = plt.figure()
    ax = fig.add_subplot(111)
#    ax = plt.axes(projection='3d')
    ax.set_xlabel('x_coord')
    ax.set_ylabel('Numerical Soln.')
    ax.set_title('CurvilinearWave 2D 72x12x2-resolution')
#    ax.scatter3D(y_iter_0,z_iter_0,num_0, c=num_0, cmap='Greens')
    ax.scatter(x_iter_0,num_0,s=2)
    savefig(filename+".png",dpi=450)
    plt.close(fig)
    i += 10

# %%
import matplotlib.image as mgimg
from matplotlib import animation

fig = plt.figure(frameon=False)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')

myimages = []

i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_72x12x2_iter_"+str(i)
    img = mgimg.imread(filename+".png")
    imgplot = plt.imshow(img)
    myimages.append([imgplot])
    i += 10

ani = animation.ArtistAnimation(fig, myimages, interval=100,  repeat_delay=1000)
plt.close()
ani.save("CurvilinearWave 2D 72x12x2_resolution.mp4", fps=5,dpi=450)

# %%
from IPython.display import HTML
#the filename needed to be changed manually

HTML("""
    <video width="480" height="360" controls>
        <source src="CurvilinearWave 2D 72x12x2_resolution.mp4" type="video/mp4"> 
    </video>
""")
# Out:
#     <video width="480" height="360" controls>
#         <source src="CurvilinearWave 2D 72x12x2_resolution.mp4" type="video/mp4">
#     </video>

# %%
itermax = 440
i = 0
while i <= itermax:
    
    filename = "Curvilinear__resolution_72x12x2_iter_"+str(i)
    x_iter_0,y_iter_0,z_iter_0,num_0,exact_0 = file_reader2(filename+".txt")
    fig = plt.figure()
    ax = fig.add_subplot(111)
#    ax = plt.axes(projection='3d')
    ax.set_xlabel('y_coord')
    ax.set_ylabel('Numerical Soln.')
    ax.set_title('CurvilinearWave 2D 72x12x2-resolution')
#    ax.scatter3D(y_iter_0,z_iter_0,num_0, c=num_0, cmap='Greens')
    ax.scatter(y_iter_0,num_0,s=2)
    savefig(filename+"_y.png",dpi=450)
    plt.close(fig)
    i += 10

# %%
import matplotlib.image as mgimg
from matplotlib import animation

fig = plt.figure(frameon=False)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')

myimages = []

i = 0
while i <= itermax:
    filename = "Curvilinear__resolution_72x12x2_iter_"+str(i)
    img = mgimg.imread(filename+"_y.png")
    imgplot = plt.imshow(img)
    myimages.append([imgplot])
    i += 10

ani = animation.ArtistAnimation(fig, myimages, interval=100,  repeat_delay=1000)
plt.close()
ani.save("CurvilinearWave 2D 72x12x2_resolution_y.mp4", fps=5,dpi=450)

# %%
from IPython.display import HTML
#the filename needed to be changed manually

HTML("""
    <video width="480" height="360" controls>
        <source src="CurvilinearWave 2D 72x12x2_resolution_y.mp4" type="video/mp4"> 
    </video>
""")
# Out:
#     <video width="480" height="360" controls>
#         <source src="CurvilinearWave 2D 72x12x2_resolution_y.mp4" type="video/mp4">
#     </video>

# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from matplotlib.pyplot import savefig
from IPython.display import HTML
import matplotlib.image as mgimg

import glob
import sys
from matplotlib import animation

globby = glob.glob('Curvilinear__resolution_72x12x2_iter_*.txt')
file_list = []
for x in sorted(globby):
    file_list.append(x)

bound=1.0
pl_xmin = -bound
pl_xmax = +bound
pl_ymin = -bound
pl_ymax = +bound

for filename in file_list:
    fig = plt.figure()
    x,y,z,cf,Ham = np.loadtxt(filename).T #Transposed for easier unpacking

    plotquantity = cf
    plotdescription = "Numerical Soln."
    plt.title("Black Hole Head-on Collision (conf factor)")
    plt.xlabel("y/M")
    plt.ylabel("z/M")

    grid_x, grid_y = np.mgrid[pl_xmin:pl_xmax:300j, pl_ymin:pl_ymax:300j]
    points = np.zeros((len(x), 2))
    for i in range(len(x)):
        # Zach says: No idea why x and y get flipped...
        points[i][0] = y[i]
        points[i][1] = x[i]

    grid = griddata(points, plotquantity, (grid_x, grid_y), method='nearest')
    gridcub = griddata(points, plotquantity, (grid_x, grid_y), method='cubic')
    im = plt.imshow(gridcub, extent=(pl_xmin,pl_xmax, pl_ymin,pl_ymax))
    ax = plt.colorbar()
    ax.set_label(plotdescription)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-136-24bc7ba87fe1> in <module>
#      38         points[i][1] = x[i]
#      39
# ---> 40     grid = griddata(points, plotquantity, (grid_x, grid_y), method='nearest')
#      41     gridcub = griddata(points, plotquantity, (grid_x, grid_y), method='cubic')
#      42     im = plt.imshow(gridcub, extent=(pl_xmin,pl_xmax, pl_ymin,pl_ymax))
#
# D:\Anaconda3\lib\site-packages\scipy\interpolate\ndgriddata.py in griddata(points, values, xi, method, fill_value, rescale)
#     216         return ip(xi)
#     217     elif method == 'nearest':
# --> 218         ip = NearestNDInterpolator(points, values, rescale=rescale)
#     219         return ip(xi)
#     220     elif method == 'linear':
#
# D:\Anaconda3\lib\site-packages\scipy\interpolate\ndgriddata.py in __init__(self, x, y, rescale, tree_options)
# ...

# %%
import numpy as np
from scipy.interpolate import griddata
import matplotlib.pyplot as plt
from matplotlib.pyplot import savefig
from IPython.display import HTML
import matplotlib.image as mgimg

import glob
import sys
from matplotlib import animation

globby = glob.glob('Curvilinear__resolution_16x8x16_iter_*.txt')
file_list = []
for x in sorted(globby):
    file_list.append(x)

bound=0.5
pl_xmin = -bound
pl_xmax = +bound
pl_ymin = -bound
pl_ymax = +bound

for filename in file_list:
    fig = plt.figure()
    x,y,cf,Ham = np.loadtxt(filename).T #Transposed for easier unpacking

    plotquantity = cf
    plotdescription = "Numerical Soln."
    plt.title("Black Hole Head-on Collision (conf factor)")
    plt.xlabel("y/M")
    plt.ylabel("z/M")

    grid_x, grid_y = np.mgrid[pl_xmin:pl_xmax:300j, pl_ymin:pl_ymax:300j]
    points = np.zeros((len(x), 2))
    for i in range(len(x)):
        # Zach says: No idea why x and y get flipped...
        points[i][0] = y[i]
        points[i][1] = x[i]

    grid = griddata(points, plotquantity, (grid_x, grid_y), method='nearest')
    gridcub = griddata(points, plotquantity, (grid_x, grid_y), method='cubic')
    im = plt.imshow(gridcub, extent=(pl_xmin,pl_xmax, pl_ymin,pl_ymax))
    ax = plt.colorbar()
    ax.set_label(plotdescription)
    savefig(filename+".png",dpi=150)
    plt.close(fig)

# %%
fig = plt.figure(frameon=False)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('off')

myimages = []

for i in range(len(file_list)):
    img = mgimg.imread(file_list[i]+".png")
    imgplot = plt.imshow(img)
    myimages.append([imgplot])

ani = animation.ArtistAnimation(fig, myimages, interval=100,  repeat_delay=1000)
plt.close()
ani.save('Curvilinear try.mp4', fps=5,dpi=150)

# %%
# %%HTML
# <video width="480" height="360" controls>
#   <source src="Curvilinear try.mp4" type="video/mp4">
# </video>
# Out:
# <video width="480" height="360" controls>
#   <source src="Curvilinear try.mp4" type="video/mp4">
# </video>
